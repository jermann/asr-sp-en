# %%
# Open the input file
with open('lexicon.txt', 'r') as f:
    # Read all lines from the file
    lines = f.readlines()

# Filter out the empty lines
non_empty_lines = [line.strip() for line in lines if line.strip()]

# Write the non-empty lines to a new file
with open('lexicon_clean.txt', 'w') as f:
    f.write('\n'.join(non_empty_lines))

# %%
import pandas as pd

# %%
df = pd.read_csv('ipa-data.csv')

# %%
df
# Out:
#      IPA_Number Symbol               Symbol_Name  \
# 0           101      p              lower-case P
# 1           102      b              lower-case B
# 2           103      t              lower-case T
# 3           104      d              lower-case D
# 4           105      ʈ              right-tail T
# ..          ...    ...                       ...
# 320         907      )         right parenthesis
# 321         908     ((   left double parenthesis
# 322         909     ))  right double parenthesis
# 323         910      {                left brace
# 324         911      }               right brace
#
#                            Description    Voicing Place_of_Articulation  \
# 0                                  NaN  voiceless              bilabial
# 1                                  NaN     voiced              bilabial
# 2                                  NaN  voiceless       dental;alveolar
# 3                                  NaN     voiced       dental;alveolar
# 4                                  NaN  voiceless             retroflex
# ..                                 ...        ...                   ...
# 320  indistinguishable utterance (end)        NaN                   NaN
# 321             sound obscured (begin)        NaN                   NaN
# 322               sound obscured (end)        NaN                   NaN
# 323            begin prosodic notation        NaN                   NaN
# 324              end prosodic notation        NaN                   NaN
#
#     Manner_of_Articulation Height Backness Rounding Status   UCS_Code  \
# 0                  plosive    NaN      NaN      NaN    NaN       0070
# 1                  plosive    NaN      NaN      NaN    NaN       0062
# 2                  plosive    NaN      NaN      NaN    NaN       0074
# 3                  plosive    NaN      NaN      NaN    NaN       0064
# 4                  plosive    NaN      NaN      NaN    NaN       0288
# ..                     ...    ...      ...      ...    ...        ...
# 320                    NaN    NaN      NaN      NaN    NaN       0029
# 321                    NaN    NaN      NaN      NaN    NaN  0028+0028
# 322                    NaN    NaN      NaN      NaN    NaN  0029+0029
# 323                    NaN    NaN      NaN      NaN    NaN       007B
# 324                    NaN    NaN      NaN      NaN    NaN       007D
#
#     AFII_Code
# 0        E2A2
# 1        E2A3
# 2        E2B0
# 3        E2B1
# 4        E2C7
# ..        ...
# 320      0029
# 321      2127
# 322      2128
# 323      007B
# 324      007D
#
# [325 rows x 13 columns]

# %%
df['Symbol']
# Out:
# 0       p
# 1       b
# 2       t
# 3       d
# 4       ʈ
#        ..
# 320     )
# 321    ((
# 322    ))
# 323     {
# 324     }
# Name: Symbol, Length: 325, dtype: object

# %%
df['Symbol'].to_csv('phones.txt', index=False, header=False)
